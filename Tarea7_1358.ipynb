# %% [markdown]
# <a href="https://colab.research.google.com/github/luis66995/EDD/blob/master/Tarea7_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 class BinaryNode:
  def __init__(self, value, left=None, right=None):
    self.data = value
    self.left = left
    self.right = right

class BinarySearchNode:
  def __init__( self ):
    self.root = None

  def insert( self, value ):
    if self.root == None:
      self.root = BinaryNode( value )
    else:
      self.__insert_nodo( self.root, value )    
    
  def __insert_nodo( self, nodo, value ):
    if nodo.data == value:
      pass
    elif value < nodo.data:   # Ir a la izquierda
      if nodo.left == None:
        nodo.left = BinaryNode( value )
      else:
        self.__insert_nodo( nodo.left, value )
    else:    # Ir a la derecha
      if nodo.right == None:
        nodo.right = BinaryNode( value )
      else:
        self.__insert_nodo( nodo.right, value )

  def transversal( self, formato = "posorden"):
    if formato == "posorden":
      self.recorrido_pos( self.root )
    elif formato == "preorden":
      self.recorrido_pre( self.root )
    else:   # Inorden
      self.recorrido_in( self.root )
    print()

  def recorrido_pos( self, nodo ):
    if nodo != None:
      self.recorrido_pos( nodo.left )
      self.recorrido_pos( nodo.right )
      print(str( nodo.data ))

  def recorrido_pre( self, nodo ):
    if nodo != None:
      print(str( nodo.data ))
      self.recorrido_pre( nodo.left )
      self.recorrido_pre( nodo.right )

  def recorrido_in( self, nodo ):
    if nodo != None:
      self.recorrido_in( nodo.left )
      print(str( nodo.data ))
      self.recorrido_in( nodo.right )

  def search( self, value ):
    if self.root == None:
      print("El árbol está vacío")
      return None
    else:
      self.__search( self.root, value )

  def __search( self, nodo, value ):
    if nodo == None:
      print("El dato no existe en el árbol")
    elif nodo.data == value:
      print("Encontrado", nodo.data)
      return nodo
    elif value < nodo.data:
      return self.__search( nodo.left, value )
    else:
      return self.__search( nodo.right, value )
  
  def delete_search(self, nodo, data):
    if nodo==None:
      return ("Nodo vacio")
    elif nodo.data==value:
      return nodo
    elif value < nodo.data:
      return self.delete_search(nodo.left, value)
    else:
      return self.delete_search(nodo.right,value)  

  def delete_nodo(self,nodo):
    if self.root==None:
       print("No existe el  arbol,Cree el arbol y sus nodos")
       return None       
    else:
      Se_Encontro.self.delete_search(self.root , value)
      if Se_Encontro.self.right==None:
         if Se_Encontro.self.left==None:
           print("Se puede eliminar la hoja del Arbol")
      elif self.recorrido_in.root.data:
        Se_Encontro= BinaryNode(Dato_En_Nodo)

# %%
arb2 = BinarySearchNode()
#1
arb2.insert(8)
arb2.insert(5)
arb2.insert(1)
arb2.insert(4)
arb2.insert(6)
arb2.insert(7)
arb2.insert(20)
arb2.insert(12)
arb2.insert(23)
arb2.search(22)
print("Eliminar valores")
arb2.delete_nodo(6)
arb2.delete_nodo(1)
arb2.delete_nodo(113)
